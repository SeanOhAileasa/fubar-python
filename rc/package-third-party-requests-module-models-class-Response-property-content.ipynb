# %% [markdown]
# # package-third-party-requests-module-models-class-Response-property-content
# > [TABLE OF CONTENTS](https://nbviewer.jupyter.org/github/SeanOhAileasa/fubar-python/blob/main/fubar-python.ipynb#top)
# ***

# %% [markdown]
# &#x2623;

# %%
# b_T_hird_P_arty-imports
#from requests.models import Response as CRp

# %% [markdown]
# &#x2623;

# %%
# package requests - module models - object Response alias CRP - attribute __doc__ - access
#print(CRp.content.__doc__)

# %%
# b_T_hird_P_arty-imports
from requests.api import get as fG
# package requests - module api - function get alias fG - call
nResponse=fG("http://api.irishrail.ie/realtime/realtime.asmx/getCurrentTrainsXML")

# %%
# package requests - module models - object Response - decorator content
nResponse.content
# Out:
# b'<?xml version="1.0" encoding="utf-8"?>\r\n<ArrayOfObjTrainPositions xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns="http://api.irishrail.ie/realtime/">\r\n  <objTrainPositions>\r\n    <TrainStatus>N</TrainStatus>\r\n    <TrainLatitude>51.9212</TrainLatitude>\r\n    <TrainLongitude>-8.17579</TrainLongitude>\r\n    <TrainCode>P279</TrainCode>\r\n    <TrainDate>19 Oct 2020</TrainDate>\r\n    <PublicMessage>P279\\nMidleton to Cork\\nExpected Departure 11:45</PublicMessage>\r\n    <Direction>To Cork</Direction>\r\n  </objTrainPositions>\r\n  <objTrainPositions>\r\n    <TrainStatus>N</TrainStatus>\r\n    <TrainLatitude>52.6587</TrainLatitude>\r\n    <TrainLongitude>-8.62397</TrainLongitude>\r\n    <TrainCode>A431</TrainCode>\r\n    <TrainDate>19 Oct 2020</TrainDate>\r\n    <PublicMessage>A431\\nLimerick to Limerick Junction\\nExpected Departure 11:50</PublicMessage>\r\n    <Direction>To Limerick Junction</Direction>\r\n  </objTrai
# ...

# %% [markdown]
# ***
# # END
