# %% [markdown]
# # package-third-party-scipy-subpackage-stats
# > [TABLE OF CONTENTS](https://nbviewer.jupyter.org/github/SeanOhAileasa/fubar-python/blob/main/fubar-python.ipynb#top)
# ***

# %% [markdown]
# - package - scipy - subpackage - stats - short for statistics [10.1]

# %%
# b_T_hird_P_arty-imports
import scipy.stats

# %%
# package scipy - subpackage stats - attribute __doc__ - access
print(scipy.stats.__doc__)
# Out:
# .. _statsrefmanual:
#
# ...
# Statistical functions (:mod:`scipy.stats`)
# ...
#
# .. currentmodule:: scipy.stats
#
# This module contains a large number of probability distributions as
# well as a growing library of statistical functions.
#
# Each univariate distribution is an instance of a subclass of `rv_continuous`
# (`rv_discrete` for discrete distributions):
#
# .. autosummary::
#    :toctree: generated/
#
#    rv_continuous
#    rv_discrete
#    rv_histogram
#
# Continuous distributions
# ...
#
# .. autosummary::
#    :toctree: generated/
#
#    alpha             -- Alpha
#    anglit            -- Anglit
#    arcsine           -- Arcsine
#    argus             -- Argus
#    beta              -- Beta
#    betaprime         -- Beta Prime
#    bradford          -- Bradford
#    burr              -- Burr (Type III)
#    burr12            -- Burr (Type XII)
#    cauchy            -- Cauchy
#    chi               -- Chi
#    chi2              -- Chi-squared
#    cosine            -- Cosine
# ...

# %%
# Kernel - Restart
exit()

# %%
# b_T_hird_P_arty-imports
import scipy.stats as ss

# %%
# package scipy - subpackage stats alias ss - attribute - __package__ - access
ss.__package__
# Out:
# 'scipy.stats'

# %%
# package scipy - subpackage stats alias ss - attribute - __path__ - access
ss.__path__
# Out:
# ['C:\\Users\\E6985\\anaconda3\\lib\\site-packages\\scipy\\stats']

# %%
# package scipy - subpackage stats alias ss - attribute - __file__ - access
ss.__file__
# Out:
# 'C:\\Users\\E6985\\anaconda3\\lib\\site-packages\\scipy\\stats\\__init__.py'

# %% [markdown]
# ***
# # END
