# %% [markdown]
# # package-third-party-matplotlib-module-pyplot-function-legend
# > [TABLE OF CONTENTS](https://nbviewer.jupyter.org/github/SeanOhAileasa/fubar-python/blob/main/fubar-python.ipynb#top)
# ***

# %%
# b_T_hird_P_arty-imports
from matplotlib.pyplot import legend as lgd

# %%
from matplotlib.style.core import use as u
u("default")

# %%
from matplotlib.pyplot import plot as p

# %%
# package matplotlib - module pyplot - function legend alias lgd - copy - attribute __doc__ - access
print(lgd.__doc__)
# Out:
# Place a legend on the axes.
#
# Call signatures::
#
#     legend()
#     legend(labels)
#     legend(handles, labels)
#
# The call signatures correspond to three different ways how to use
# this method.
#
# **1. Automatic detection of elements to be shown in the legend**
#
# The elements to be added to the legend are automatically determined,
# when you do not pass in any extra arguments.
#
# In this case, the labels are taken from the artist. You can specify
# them either at artist creation or by calling the
# :meth:`~.Artist.set_label` method on the artist::
#
#     line, = ax.plot([1, 2, 3], label='Inline label')
#     ax.legend()
#
# or::
#
#     line, = ax.plot([1, 2, 3])
#     line.set_label('Label via method')
#     ax.legend()
#
# Specific lines can be excluded from the automatic legend element
# selection by defining a label starting with an underscore.
# This is default for all artists, so calling `Axes.legend` without
# ...

# %% [markdown]
# - adding legend - two or more different plots on the one set of axes - differentiating the different items represented on the plot [2.2]

# %% [markdown]
# - adding a legend to the plot - must first give argument - ``label`` - to each of the individual items to be plotted before call function - legend [2.2]

# %%
# package matplotlib - module pyplot - function plot alias p - call
p([1,2,3,4],[1,4,9,16],"r+",label="squares")
p([1,2,3,4],[1,8,27,64],"b-",label="cubes")
# package matplotlib - module - pyplot - function legend alias ldg - call
lgd()

# %% [markdown]
# ***
# # END
