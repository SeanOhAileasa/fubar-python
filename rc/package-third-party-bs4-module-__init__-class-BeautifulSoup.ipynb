# %% [markdown]
# # package-third-party-bs4-module-__init__-class-BeautifulSoup
# > [TABLE OF CONTENTS](https://nbviewer.jupyter.org/github/SeanOhAileasa/fubar-python/blob/main/fubar-python.ipynb#top)
# ***

# %%
# b_T_hird_P_arty-imports
from bs4 import BeautifulSoup as CBSoup

# %%
# package bs4 - module __init__ - object BeautifulSoup alias CBSoup - attribute __doc__ - access
print(CBSoup.__doc__)
# Out:
# A data structure representing a parsed HTML or XML document.
#
#     Most of the methods you'll call on a BeautifulSoup object are inherited from
#     PageElement or Tag.
#
#     Internally, this class defines the basic interface called by the
#     tree builders when converting an HTML/XML document into a data
#     structure. The interface abstracts away the differences between
#     parsers. To write a new tree builder, you'll need to understand
#     these methods as a whole.
#
#     These methods will be called by the BeautifulSoup constructor:
#       * reset()
#       * feed(markup)
#
#     The tree builder may call these methods from its feed() implementation:
#       * handle_starttag(name, attrs) # See note about return value
#       * handle_endtag(name)
#       * handle_data(data) # Appends to the current data node
#       * endData(containerClass) # Ends the current data node
#
#     No matter how complicated the underlying parser is, you should be
# ...

# %%
# b_T_hird_P_arty-imports
from requests.api import get as fG
# package requests - module api - function get alias fG - call
nResponse=fG("http://api.irishrail.ie/realtime/realtime.asmx/getCurrentTrainsXML")

# %%
# package bs4 - module __init__ - object BeautifulSoup alias CBSoup - instantiate
CBSoup(nResponse.content,"xml")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <ArrayOfObjTrainPositions xmlns="http://api.irishrail.ie/realtime/" xmlns:xsd="http://www.w3.org/2001/XMLSchema" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>51.8491</TrainLatitude>
# <TrainLongitude>-8.29956</TrainLongitude>
# <TrainCode>P241</TrainCode>
# <TrainDate>19 Oct 2020</TrainDate>
# <PublicMessage>P241\nCobh to Cork\nExpected Departure 11:30</PublicMessage>
# <Direction>To Cork</Direction>
# </objTrainPositions>
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# <TrainLatitude>51.9018</TrainLatitude>
# <TrainLongitude>-8.4582</TrainLongitude>
# <TrainCode>A213</TrainCode>
# <TrainDate>19 Oct 2020</TrainDate>
# <PublicMessage>A213\nCork to Dublin Heuston\nExpected Departure 11:25</PublicMessage>
# <Direction>To Dublin Heuston</Direction>
# </objTrainPositions>
# <objTrainPositions>
# <TrainStatus>N</TrainStatus>
# ...

# %% [markdown]
# ***
# # END
